# %% [markdown]
# ## Settings

# %%
import pandas as pd

# %%
# Get paths
paths = pd.read_csv("../apollo_filepaths.csv")
vcf_paths = paths[paths['result_type'] == 'consensus_somatic_maf']
vcf_paths = vcf_paths[['isabl_patient_id', 'isabl_sample_id', 'result_filepath']]

# %%
vcf_paths
# Out:
#      isabl_patient_id isabl_sample_id  \
# 9                A001        ADT001R1
# 31               A029        ADT029R1
# 53               A034        ADT034R1
# 75               A036        ADT036R1
# 97               A042        ADT042R1
# ...               ...             ...
# 5839             A044        ADHMB044
# 5861             A105        ADHMB105
# 5883             A096        ADHMB096
# 5905             A091        ADHMB091
# 5927             A082        ADHMB082
#
#                                         result_filepath
# 9     /juno/work/shah/isabl_data_lake/analyses/13/46...
# 31    /juno/work/shah/isabl_data_lake/analyses/13/47...
# 53    /juno/work/shah/isabl_data_lake/analyses/13/48...
# 75    /juno/work/shah/isabl_data_lake/analyses/13/49...
# 97    /juno/work/shah/isabl_data_lake/analyses/13/50...
# ...                                                 ...
# 5839  /juno/work/shah/isabl_data_lake/analyses/10/83...
# 5861  /juno/work/shah/isabl_data_lake/analyses/10/84...
# 5883  /juno/work/shah/isabl_data_lake/analyses/10/85...
# 5905  /juno/work/shah/isabl_data_lake/analyses/10/86...
# 5927  /juno/work/shah/isabl_data_lake/analyses/10/87...
#
# [270 rows x 3 columns]

# %%
vcf_paths['isabl_sample_id'].values[:]
# Out:
# array(['ADT001R1', 'ADT029R1', 'ADT034R1', 'ADT036R1', 'ADT042R1',
#        'ADT043R1', 'ADT046R1', 'ADT047R1', 'ADT067R1', 'ADT068R1',
#        'ADT074R1', 'ADT079R1', 'ADT084R1', 'ADT089R1', 'ADT091R1',
#        'ADT096R2', 'ADT101R1', 'ADT106R2', 'ADT165R2', 'ADT167R2',
#        'ADT064R1', 'ADH001', 'ADT001', 'ADH002', 'ADT002', 'ADH005',
#        'ADT005', 'ADH007', 'ADT007', 'ADH009', 'ADT009', 'ADT009R',
#        'ADH011', 'ADT011', 'ADH014', 'ADT014', 'ADH016', 'ADT016',
#        'ADH017', 'ADT017', 'ADH018', 'ADT018', 'ADH019', 'ADT019',
#        'ADH020', 'ADT020', 'ADH021', 'ADT021', 'ADH022', 'ADT022',
#        'ADH024', 'ADT024', 'ADH025', 'ADT025', 'ADH026', 'ADT026',
#        'ADH028', 'ADT028', 'ADH029', 'ADT029', 'ADH030', 'ADT030',
#        'ADH031', 'ADT031', 'ADH032', 'ADT032', 'ADH033', 'ADT033',
#        'ADH034', 'ADT034', 'ADH035', 'ADT035', 'ADH036', 'ADT036',
#        'ADH038', 'ADT038', 'ADH040', 'ADT040', 'ADH042', 'ADT042',
#        'ADH043', 'ADT043', 'ADH044', 'ADT044', 'ADH046', 'ADT046',
#        'ADH047', 'ADT047', 'ADH048', 'ADT048', 'ADH049', 'ADT049',
#        'ADH050', 'ADH050R', 'ADT050R', 'ADH052', 'ADT052', 'ADH053',
#        'ADT053', 'ADH054', 'ADT054', 'ADH055', 'ADT055', 'ADH056',
#        'ADT056', 'ADH057', 'ADT057', 'ADH058', 'ADT058', 'ADH061',
#        'ADT061', 'ADH062', 'ADT062', 'ADH063', 'ADT063', 'ADH064R',
#        'ADT064', 'ADH065', 'ADT065', 'ADH066', 'ADH066-2', 'ADT066',
#        'ADH067', 'ADT067', 'ADH068', 'ADT068', 'ADH071', 'ADH072',
#        'ADT072', 'ADH073', 'ADT073', 'ADH074', 'ADT074', 'ADH075',
#        'ADT075', 'ADH076', 'ADT076', 'ADH077', 'ADT077', 'ADH079',
#        'ADT079', 'ADH080', 'ADT080', 'ADH081', 'ADT081', 'ADH082',
#        'ADT082', 'ADH083', 'ADT083', 'ADH084', 'ADT084', 'ADH085',
#        'ADT085', 'ADH086', 'ADT086', 'ADH087', 'ADT087', 'ADH088',
#        'ADT088', 'ADH089', 'ADT089', 'ADH090', 'ADT090', 'ADH091',
#        'ADT091', 'ADH092', 'ADH094', 'ADT094', 'ADH095', 'ADT095',
#        'ADH096', 'ADT096', 'ADH098', 'ADT098', 'ADH100', 'ADT100',
#        'ADH101', 'ADT101', 'ADH102', 'ADT102', 'ADH103R', 'ADT103',
#        'ADH105', 'ADT105', 'ADH106', 'ADT106', 'ADH110', 'ADT110',
#        'ADH111', 'ADT111', 'ADH112', 'ADT112', 'ADH113', 'ADT113',
#        'ADH115', 'ADT115', 'ADH118', 'ADT118', 'ADH120', 'ADT120',
#        'ADT121', 'ADH126', 'ADH138', 'ADT138', 'ADH165', 'ADT165',
#        'ADH166', 'ADT166', 'ADH167', 'ADT167', 'ADH168', 'ADT168',
#        'ADH169', 'ADT169', 'ADH170', 'ADT170', 'ADH171', 'ADT171',
#        'ADH172', 'ADT172', 'ADH175', 'ADT175', 'ADH177', 'ADT177',
#        'ADH185', 'ADH185R', 'ADT185', 'ADT185R', 'ADH188', 'ADT188',
#        'ADH254', 'ADT254', 'ADT126', 'ADT092', 'ADTMB028', 'ADTMB072',
#        'ADTMB044', 'ADTMB001', 'ADTMB113', 'ADTMB029', 'ADTMB106',
#        'ADTMB096', 'ADTMB094', 'ADTMB080', 'ADHMB028', 'ADHMB016',
#        'ADHMB188', 'ADHMB168', 'ADHMB113', 'ADHMB112', 'ADHMB029',
#        'ADHMB009', 'ADHMB002', 'ADHMB001', 'ADHMB072', 'ADHMB063',
#        'ADHMB038', 'ADHMB035', 'ADHMB166', 'ADHMB106', 'ADHMB103',
#        'ADHMB094', 'ADHMB086', 'ADHMB085', 'ADHMB079', 'ADHMB044',
#        'ADHMB105', 'ADHMB096', 'ADHMB091', 'ADHMB082'], dtype=object)

# %% [markdown]
# ## Functions

# %%
def get_somatic_mutation_count(maf):
    tb = pd.read_table(maf, low_memory=False, header=1)
    flt = tb[tb.Variant_Classification.isin(class_to_include)]
    return flt.shape[0]

def get_neoepitope_count(tsv):
    tb = pd.read_table(tsv, low_memory=False)
    strongs = tb[tb['Best MT Score'] < 150]
    weaks = tb[(tb['Best MT Score'] >= 150) & (tb['Best MT Score'] < 500)]
    return tb.shape[0], strongs.shape[0], weaks.shape[0]

# %%
tb = pd.read_table(maf, low_memory=False, header=1)
tb.head(10)
# Out:
#        Hugo_Symbol  Entrez_Gene_Id Center NCBI_Build Chromosome  \
# 0          OR4G11P               0      .     GRCh37          1
# 1     RP5-857K21.4               0      .     GRCh37          1
# 2           FAM87B               0      .     GRCh37          1
# 3             AGRN               0      .     GRCh37          1
# 4             AGRN               0      .     GRCh37          1
# 5  ENSR00000344333               0      .     GRCh37          1
# 6            SSU72               0      .     GRCh37          1
# 7          Unknown               0      .     GRCh37          1
# 8          SLC35E2               0      .     GRCh37          1
# 9            PRKCZ               0      .     GRCh37          1
#
#    Start_Position  End_Position Strand Variant_Classification Variant_Type  \
# 0           61219         61219      +                5'Flank          SNP
# 1          604723        604723      +                 Intron          SNP
# 2          757834        757834      +                3'Flank          SNP
# 3          959597        959597      +                 Intron          SNP
# 4          991839        991839      +                3'Flank          SNP
# 5         1056881       1056881      +                    IGR          SNP
# 6         1506814       1506814      +                 Intron          SNP
# 7         1522501       1522501      +                    IGR          SNP
# 8         1669931       1669931      +                 Intron          SNP
# 9         2110591       2110591      +                 Intron          SNP
#
#    ... gnomAD_AF gnomAD_AFR_AF gnomAD_AMR_AF gnomAD_ASJ_AF  gnomAD_EAS_AF  \
# 0  ...       NaN           NaN           NaN           NaN            NaN
# 1  ...       NaN           NaN           NaN           NaN            NaN
# 2  ...       NaN           NaN           NaN           NaN            NaN
# 3  ...       NaN           NaN           NaN           NaN            NaN
# 4  ...       NaN           NaN           NaN           NaN            NaN
# 5  ...       NaN           NaN           NaN           NaN            NaN
# 6  ...       NaN           NaN           NaN           NaN            NaN
# 7  ...       NaN           NaN           NaN           NaN            NaN
# 8  ...       NaN           NaN           NaN           NaN            NaN
# 9  ...       NaN           NaN           NaN           NaN            NaN
#
#   gnomAD_FIN_AF gnomAD_NFE_AF gnomAD_OTH_AF gnomAD_SAS_AF  vcf_pos
# 0           NaN           NaN           NaN           NaN    61219
# 1           NaN           NaN           NaN           NaN   604723
# 2           NaN           NaN           NaN           NaN   757834
# 3           NaN           NaN           NaN           NaN   959597
# 4           NaN           NaN           NaN           NaN   991839
# 5           NaN           NaN           NaN           NaN  1056881
# 6           NaN           NaN           NaN           NaN  1506814
# 7           NaN           NaN           NaN           NaN  1522501
# 8           NaN           NaN           NaN           NaN  1669931
# 9           NaN           NaN           NaN           NaN  2110591
#
# [10 rows x 133 columns]

# %%
tb['Consequence'].value_counts()
# Out:
# intergenic_variant                                                    10978
# intron_variant                                                         8696
# intron_variant,non_coding_transcript_variant                           2995
# downstream_gene_variant                                                1614
# upstream_gene_variant                                                  1547
# regulatory_region_variant                                               990
# 3_prime_UTR_variant                                                     137
# non_coding_transcript_exon_variant                                      102
# missense_variant                                                         69
# intron_variant,NMD_transcript_variant                                    63
# synonymous_variant                                                       37
# 5_prime_UTR_variant                                                      20
# splice_region_variant,intron_variant,non_coding_transcript_variant       10
# inframe_deletion                                                          7
# splice_region_variant,intron_variant                                      5
# missense_variant,splice_region_variant                                    3
# splice_region_variant,synonymous_variant                                  3
# stop_gained                                                               2
# mature_miRNA_variant                                                      2
# splice_region_variant,non_coding_transcript_exon_variant                  2
# inframe_insertion                                                         1
# splice_donor_variant                                                      1
# splice_acceptor_variant,non_coding_transcript_variant                     1
# splice_acceptor_variant                                                   1
# Name: Consequence, dtype: int64

# %%
tb['Variant_Classification'].value_counts()
# Out:
# IGR                  11968
# Intron               11754
# 3'Flank               1614
# 5'Flank               1547
# 3'UTR                  137
# RNA                    104
# Missense_Mutation       72
# Silent                  37
# 5'UTR                   20
# Splice_Region           20
# In_Frame_Del             7
# Splice_Site              3
# Nonsense_Mutation        2
# In_Frame_Ins             1
# Name: Variant_Classification, dtype: int64

# %%
class_to_include = [ # according to Mutation_Annotation_Format_TCGAv2
    "Frame_Shift_Del",
    "Frame_Shift_Ins",
    "In_Frame_Del",
    "In_Frame_Ins",
    "Missense_Mutation",
    "Nonsense_Mutation",
    # "Silent",
    "Splice_Site",
    "Translation_Start_Site",
    "Nonstop_Mutation",
    # "RNA",
    "Targeted_Region",
    "De_novo_Start_InFrame",
    "De_novo_Start_OutOfFrame",
]

# %%
flt = tb[tb.Variant_Classification.isin(class_to_include)]

# %%
flt.shape
# Out:
# (1439, 133)

# %%
flt.shape[0]
# Out:
# 1439

# %% [markdown]
# ## TSV (neoepitopes) count

# %%
tb = pd.read_table(tsv, low_memory=False)
print(tb.shape)
tb.head(10)
# Out:
# (32, 73)
#   Chromosome      Start       Stop   Reference Variant       Transcript  \
# 0         19   11027426   11027427           G       A  ENST00000327064
# 1          5  154278166  154278167           C       T  ENST00000285873
# 2          2  103142743  103142752  TCTCCTACCC       T  ENST00000295269
# 3         16    2811887    2811890        TTTC       T  ENST00000301740
# 4         11  122828071  122828072           C       T  ENST00000227349
# 5         17   21319078   21319079           C       A  ENST00000331718
# 6          X   36324968   36324969           G       A  ENST00000378653
# 7         11   61096910   61096911           C       T  ENST00000301764
# 8         22   46654470   46654471           C       A  ENST00000253255
# 9         17    7577093    7577094           G       A  ENST00000269305
#
#    Transcript Support Level  Ensembl Gene ID Variant Type Mutation  ...  \
# 0                       NaN  ENSG00000142453     missense      D/N  ...
# 1                       NaN  ENSG00000082516     missense      A/T  ...
# 2                       NaN  ENSG00000180251  inframe_del   LSYP/L  ...
# 3                       NaN  ENSG00000167978  inframe_del     IS/I  ...
# 4                       NaN  ENSG00000109944     missense      T/M  ...
# 5                       NaN  ENSG00000184185     missense      T/N  ...
# 6                       NaN  ENSG00000205081     missense      C/Y  ...
# 7                       NaN  ENSG00000167986     missense      R/H  ...
# 8                       NaN  ENSG00000130943     missense      L/F  ...
# 9                       NaN  ENSG00000141510     missense      R/W  ...
#
#   SMMPMBEC MT Percentile                                              Index  \
# 0                    0.5          189.CARM1.ENST00000327064.missense.332D/N
# 1                    0.8         59.GEMIN5.ENST00000285873.missense.1060A/T
# 2                    0.3  34.SLC9A4.ENST00000295269.inframe_del.659-662L...
# 3                    1.3  170.SRRM2.ENST00000301740.inframe_del.453-454IS/I
# 4                    1.0       137.C11orf63.ENST00000227349.missense.671T/M
# 5                    NaN         182.KCNJ12.ENST00000331718.missense.142T/N
# 6                    NaN        214.CXorf30.ENST00000378653.missense.453C/Y
# 7                    NaN           111.DDB1.ENST00000301764.missense.158R/H
# 8                    NaN        213.PKDREJ.ENST00000253255.missense.1583L/F
# 9                    1.5           174.TP53.ENST00000269305.missense.282R/W
#
#   cterm_7mer_gravy_score max_7mer_gravy_score difficult_n_terminal_residue  \
# 0              -0.571429             0.328571                        False
# 1              -0.371429             0.500000                        False
# 2              -0.885714            -0.800000                        False
# 3              -2.257143            -0.528571                         True
# 4              -1.842857            -1.400000                         True
# 5              -0.414286            -0.414286                        False
# 6              -0.128571             0.428571                        False
# 7              -0.228571             0.385714                        False
# 8               0.485714             1.571429                        False
# 9              -1.842857            -0.457143                         True
#
#    c_terminal_cysteine  c_terminal_proline  cysteine_count  \
# 0                False               False               0
# 1                False               False               0
# 2                False               False               0
# 3                False               False               0
# 4                False               False               0
# 5                False               False               0
# 6                False               False               1
# 7                False               False               0
# 8                False               False               0
# 9                False               False               2
#
#   n_terminal_asparagine asparagine_proline_bond_count
# 0                 False                             0
# 1                 False                             0
# 2                 False                             0
# 3                 False                             0
# 4                 False                             0
# 5                 False                             0
# 6                 False                             0
# 7                 False                             0
# 8                 False                             0
# 9                 False                             0
#
# [10 rows x 73 columns]

# %% [markdown]
# ## Get somatic mutation and neoepitope counts

# %%
# example paths
maf = '/juno/work/shah/isabl_data_lake/analyses/56/53/15653/results/somatic/ADT001/ADT001_consensus_somatic.maf'
tsv = '/juno/work/shah/users/chois7/apollo/neoantigen/main_run/A001/ADH001/outputs/pvacseq/MHC_Class_I/ADH001.filtered.tsv'

# %%
import os
n = 0
patient_samples = dict()
patients = vcf_paths['isabl_patient_id'].unique()
for patient in patients:
    sample_paths = vcf_paths[vcf_paths['isabl_patient_id'] == patient]
    samples = sample_paths['isabl_sample_id']
    
    for sample in samples:
        maf = sample_paths[sample_paths['isabl_sample_id'] == sample]['result_filepath'].values[0]
        tsv = f'/juno/work/shah/users/chois7/apollo/neoantigen/main_run/{patient}/{sample}/outputs/pvacseq/MHC_Class_I/{sample}.filtered.tsv'
        assert os.path.isfile(maf), f"ERROR: {maf} does not exist."
        if os.path.isfile(tsv):
            somatic_mutation_count = get_somatic_mutation_count(maf)
            neoepitope_count, strong_count, weak_count = get_neoepitope_count(tsv)
            print(f'{patient}\t{sample}\t{somatic_mutation_count}\t{neoepitope_count}\t{strong_count}\t{weak_count}')
# Out:
# A001	ADT001R1	164	30	25	5
# A001	ADH001	85	32	28	4
# A001	ADTMB001	147	41	38	3
# A001	ADHMB001	111	0	0	0
# A029	ADT029R1	197	29	29	0
# A029	ADH029	94	4	4	0
# A029	ADT029	105	9	9	0
# A029	ADTMB029	120	20	20	0
# A029	ADHMB029	125	4	4	0
# A034	ADT034R1	165	56	53	3
# A034	ADH034	93	45	43	2
# A034	ADT034	94	45	43	2
# A036	ADT036R1	279	29	27	2
# A036	ADH036	153	12	12	0
# A036	ADT036	172	24	23	1
# A042	ADT042R1	116	31	30	1
# A042	ADH042	58	20	18	2
# A042	ADT042	46	22	20	2
# A043	ADT043R1	165	1	1	0
# A043	ADH043	96	1	0	1
# A046	ADT046R1	116	17	17	0
# A046	ADH046	40	7	7	0
# A046	ADT046	40	7	7	0
# A047	ADT047	68	11	8	3
# A067	ADT067R1	230	28	26	2
# A067	ADH067	115	19	17	2
# A067	ADT067	119	25	22	3
# A068	ADT068R1	219	87	79	8
# A068	ADH068	144	79	71	8
# A068	ADT068	151	81	74	7
# A074	ADT074R1	135	21	20	1
# A074	ADH074	75	5	5	0
# A074	ADT074	78	17	16	1
# A079	ADT079R1	223	17	16	1
# A079	ADH079	152	14	13	1
# A079	ADT079	155	19	18	1
# A079	ADHMB079	228	15	14	1
# A084	ADT084R1	153	31	29	2
# A084	ADH084	113	22	20	2
# A084	ADT084	96	20	19	1
# A089	ADT089R1	190	22	20	2
# A089	ADH089	112	16	15	1
# A089	ADT089	120	18	16	2
# A091	ADT091R1	309	98	87	11
# A091	ADH091	217	30	26	4
# A091	ADT091	230	95	86	9
# A091	ADHMB091	224	94	84	10
# A096	ADT096R2	219	62	54	8
# A096	ADH096	143	54	47	7
# A096	ADHMB096	148	50	45	5
# A101	ADT101R1	158	35	34	1
# A101	ADH101	69	31	31	0
# A101	ADT101	77	31	31	0
# A106	ADT106R2	115	8	8	0
# A106	ADH106	59	14	13	1
# A106	ADTMB106	59	11	11	0
# A106	ADHMB106	74	2	2	0
# A165	ADT165R2	170	10	10	0
# A165	ADH165	148	10	9	1
# A167	ADT167R2	144	21	21	0
# A167	ADH167	58	13	13	0
# A064	ADT064R1	216	55	48	7
# A064	ADH064R	154	34	33	1
# A064	ADT064	152	48	44	4
# A002	ADH002	107	20	17	3
# A002	ADT002	95	22	19	3
# A002	ADHMB002	110	23	19	4
# A005	ADH005	57	6	6	0
# A005	ADT005	60	20	20	0
# A007	ADH007	52	20	20	0
# A007	ADT007	56	18	18	0
# A009	ADH009	38	22	17	5
# A009	ADT009	47	24	19	5
# A009	ADT009R	51	23	18	5
# A009	ADHMB009	92	16	11	5
# A011	ADH011	70	5	5	0
# A011	ADT011	68	12	12	0
# A014	ADH014	62	36	35	1
# A014	ADT014	64	37	37	0
# A016	ADH016	92	26	25	1
# A016	ADT016	102	27	26	1
# A016	ADHMB016	97	16	15	1
# A017	ADH017	115	54	52	2
# A017	ADT017	116	55	53	2
# A018	ADH018	18	4	4	0
# A018	ADT018	22	4	4	0
# A019	ADH019	197	38	36	2
# A019	ADT019	249	67	64	3
# A020	ADH020	93	20	20	0
# A020	ADT020	91	33	30	3
# A021	ADH021	136	9	9	0
# A021	ADT021	140	48	44	4
# A022	ADH022	115	10	10	0
# A022	ADT022	131	39	37	2
# A024	ADH024	97	19	18	1
# A024	ADT024	118	28	27	1
# A025	ADH025	152	32	31	1
# A025	ADT025	141	32	31	1
# A026	ADH026	88	2	2	0
# A026	ADT026	90	17	17	0
# A028	ADH028	70	33	33	0
# A028	ADT028	76	33	33	0
# A028	ADTMB028	84	35	35	0
# A030	ADH030	29	3	3	0
# A030	ADT030	48	6	6	0
# A031	ADH031	61	10	9	1
# A031	ADT031	59	14	13	1
# A032	ADH032	52	21	19	2
# A032	ADT032	60	20	18	2
# A033	ADH033	176	24	21	3
# A033	ADT033	189	30	27	3
# A035	ADH035	72	10	9	1
# A035	ADT035	99	24	23	1
# A035	ADHMB035	98	19	19	0
# A038	ADH038	169	52	51	1
# A038	ADT038	182	60	58	2
# A038	ADHMB038	176	6	6	0
# A040	ADH040	94	32	28	4
# A044	ADH044	82	2	2	0
# A044	ADT044	79	30	28	2
# A044	ADTMB044	119	30	26	4
# A044	ADHMB044	79	5	5	0
# A048	ADH048	35	0	0	0
# A048	ADT048	112	54	51	3
# A049	ADH049	47	4	4	0
# A049	ADT049	154	5	4	1
# A050	ADH050	129	17	15	2
# A050	ADH050R	133	16	14	2
# A050	ADT050R	176	40	36	4
# A052	ADH052	60	5	5	0
# A052	ADT052	73	17	17	0
# A053	ADH053	75	2	2	0
# A053	ADT053	79	17	16	1
# A054	ADH054	189	29	27	2
# A055	ADH055	141	6	6	0
# A055	ADT055	164	55	52	3
# A056	ADH056	65	7	6	1
# A056	ADT056	87	29	28	1
# A057	ADH057	72	1	1	0
# A058	ADH058	105	29	25	4
# A058	ADT058	104	30	26	4
# A061	ADH061	63	11	11	0
# A061	ADT061	81	18	18	0
# A062	ADH062	87	4	4	0
# A062	ADT062	95	22	21	1
# A063	ADH063	108	16	15	1
# A063	ADT063	119	40	38	2
# A063	ADHMB063	49	0	0	0
# A065	ADH065	107	28	26	2
# A065	ADT065	122	29	27	2
# A066	ADH066	88	14	13	1
# A066	ADH066-2	96	12	10	2
# A066	ADT066	132	14	13	1
# A071	ADH071	62	17	17	0
# A072	ADH072	162	60	53	7
# A072	ADT072	170	67	59	8
# A072	ADTMB072	202	64	56	8
# A072	ADHMB072	205	54	46	8
# A073	ADH073	70	9	9	0
# A073	ADT073	90	30	30	0
# A075	ADH075	101	14	12	2
# A075	ADT075	114	24	22	2
# A076	ADH076	122	16	15	1
# A076	ADT076	146	35	31	4
# A077	ADH077	74	34	32	2
# A077	ADT077	88	37	35	2
# A080	ADH080	52	12	12	0
# A080	ADT080	73	20	19	1
# A080	ADTMB080	81	17	17	0
# A081	ADH081	68	13	10	3
# A081	ADT081	60	12	9	3
# A082	ADH082	201	45	42	3
# A082	ADHMB082	201	1	1	0
# A083	ADH083	90	9	9	0
# A083	ADT083	93	28	26	2
# A085	ADH085	93	33	30	3
# A085	ADT085	103	37	33	4
# A085	ADHMB085	117	0	0	0
# A086	ADH086	65	11	11	0
# A086	ADT086	76	22	20	2
# A086	ADHMB086	68	7	7	0
# A087	ADH087	107	35	33	2
# A087	ADT087	133	34	31	3
# A088	ADH088	183	34	31	3
# A088	ADT088	243	54	50	4
# A090	ADH090	57	4	4	0
# A090	ADT090	73	6	6	0
# A092	ADH092	54	9	9	0
# A092	ADT092	63	21	21	0
# A094	ADH094	78	13	13	0
# A094	ADT094	85	22	22	0
# A094	ADTMB094	105	22	22	0
# A095	ADH095	158	24	24	0
# A095	ADT095	156	40	40	0
# A098	ADH098	59	4	4	0
# A098	ADT098	61	17	17	0
# A100	ADH100	137	29	27	2
# A100	ADT100	150	32	31	1
# A102	ADH102	250	112	107	5
# A102	ADT102	288	119	114	5
# A103	ADH103R	73	16	16	0
# A103	ADT103	71	22	22	0
# A103	ADHMB103	111	19	19	0
# A105	ADH105	238	53	49	4
# A105	ADT105	260	100	94	6
# A105	ADHMB105	246	55	51	4
# A110	ADH110	50	14	14	0
# A110	ADT110	55	18	17	1
# A111	ADH111	206	46	40	6
# A111	ADT111	200	39	34	5
# A112	ADH112	182	74	67	7
# A112	ADHMB112	113	11	10	1
# A113	ADH113	98	9	9	0
# A113	ADT113	103	23	23	0
# A113	ADTMB113	99	26	24	2
# A113	ADHMB113	61	4	3	1
# A115	ADH115	65	0	0	0
# A115	ADT115	87	3	3	0
# A118	ADH118	43	1	1	0
# A118	ADT118	80	20	17	3
# A120	ADH120	51	0	0	0
# A120	ADT120	61	1	1	0
# A121	ADT121	86	30	27	3
# A126	ADH126	46	2	2	0
# A126	ADT126	17	2	2	0
# A138	ADH138	30	0	0	0
# A138	ADT138	116	15	14	1
# A166	ADH166	64	15	15	0
# A166	ADT166	64	15	15	0
# A166	ADHMB166	69	14	14	0
# A168	ADH168	112	37	32	5
# A168	ADT168	125	39	34	5
# A168	ADHMB168	96	10	10	0
# A169	ADH169	100	4	3	1
# A169	ADT169	119	34	33	1
# A170	ADH170	115	2	2	0
# A170	ADT170	138	34	33	1
# A171	ADH171	129	3	3	0
# A172	ADH172	39	2	2	0
# A172	ADT172	69	25	21	4
# A175	ADH175	62	12	11	1
# A175	ADT175	57	15	12	3
# A177	ADH177	204	4	4	0
# A177	ADT177	202	35	34	1
# A185	ADH185	68	1	1	0
# A185	ADH185R	73	1	1	0
# A185	ADT185	89	13	13	0
# A185	ADT185R	89	14	14	0
# A188	ADH188	65	18	17	1
# A188	ADT188	68	21	19	2
# A188	ADHMB188	53	19	18	1
# A254	ADH254	83	28	23	5
# A254	ADT254	82	27	25	2

# %% [markdown]
# ## Plot count distribution between groups

# %%
labels_path = "/juno/work/shah/users/chois7/apollo/database/annotated_signatures.csv"
labels = pd.read_table(labels_path, sep=',', index_col=0, header=0, # override col names
                       names=['sample', 'cluster_id', 'patient', 'source', 'signature'])
print(labels.shape)
labels.head()
# Out:
# (138, 4)
#         cluster_id patient          source signature
# sample
# ADH105           4    A105     Whole_Tumor   HRD-Del
# ADT105           4    A105  Enriched_Tumor   HRD-Del
# ADH088           4    A088     Whole_Tumor   HRD-Del
# ADT088           4    A088  Enriched_Tumor   HRD-Del
# ADH087           4    A087     Whole_Tumor   HRD-Del

# %%
knns_path = "/juno/work/shah/users/chois7/apollo/database/knn_signatures.csv"
knns = pd.read_table(knns_path, sep=',', index_col=0, header=0, # override col names
                     names=['sample', 'knn'])
print(knns.shape)
knns.head()
# Out:
# (301, 1)
#           knn
# sample
# ADH001  CDK12
# ADH002  CCNE1
# ADH005  BRCA1
# ADH007  CCNE1
# ADH009  CDK12

# %%
counts_path = "counts/counts.txt"
counts = pd.read_table(counts_path, sep='\t', index_col=1)
counts['w/s_ratio'] = (counts['weak'] / counts['strong']).fillna(0)
counts = counts.replace([np.inf, -np.inf], np.nan).fillna(0)
print(counts.shape)
counts.head()
# Out:
# (253, 6)
#          patient  somatic  neoepitope  strong  weak  w/s_ratio
# sample
# ADT001R1    A001      164          30      25     5   0.200000
# ADH001      A001       85          32      28     4   0.142857
# ADTMB001    A001      147          41      38     3   0.078947
# ADHMB001    A001      111           0       0     0   0.000000
# ADT029R1    A029      197          29      29     0   0.000000

# %%
counts = counts.join(labels[['source', 'signature']])
counts = counts.dropna(how='any') # drop non-n69 # not full yet d/t runs not completed

counts = counts.join(knns[['knn']])
counts = counts.dropna(how='any') # drop non-n69 # not full yet d/t runs not completed
counts['signature'] = counts['knn']
counts = counts[['patient', 'somatic', 'neoepitope', 'strong', 'weak', 'w/s_ratio', 'source', 'signature']]

# %%
counts
# Out:
#          patient  somatic  neoepitope  strong  weak  w/s_ratio  \
# sample
# ADT001R1    A001      164          30      25     5   0.200000
# ADH001      A001       85          32      28     4   0.142857
# ADT029R1    A029      197          29      29     0   0.000000
# ADH029      A029       94           4       4     0   0.000000
# ADT034R1    A034      165          56      53     3   0.056604
# ...          ...      ...         ...     ...   ...        ...
# ADT172      A172       69          25      21     4   0.190476
# ADH175      A175       62          12      11     1   0.090909
# ADT175      A175       57          15      12     3   0.250000
# ADH188      A188       65          18      17     1   0.058824
# ADT188      A188       68          21      19     2   0.105263
#
#                   source signature
# sample
# ADT001R1  Enriched_Tumor     CDK12
# ADH001       Whole_Tumor     CDK12
# ADT029R1  Enriched_Tumor     CCNE1
# ADH029       Whole_Tumor     CCNE1
# ADT034R1  Enriched_Tumor     BRCA1
# ...                  ...       ...
# ADT172    Enriched_Tumor     CCNE1
# ADH175       Whole_Tumor     CCNE1
# ADT175    Enriched_Tumor     CCNE1
# ADH188       Whole_Tumor     CCNE1
# ADT188    Enriched_Tumor     CCNE1
#
# [132 rows x 8 columns]

# %%
counts.signature.value_counts()
# Out:
# CCNE1    70
# BRCA1    36
# CDK12    16
# BRCA2    10
# Name: signature, dtype: int64

# %% [markdown]
# ### Get matched counts

# %%
whole_tumors = counts[counts.source == 'Whole_Tumor']
whole_tumors['sample'] = list(whole_tumors.index)
whole_tumors = whole_tumors.set_index(whole_tumors['patient'])
enriched_tumors = counts[counts.source == 'Enriched_Tumor']
enriched_tumors['sample'] = list(enriched_tumors.index)
enriched_tumors = enriched_tumors.set_index(enriched_tumors['patient'])
# Out:
# <ipython-input-421-5349a79c4939>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   whole_tumors['sample'] = list(whole_tumors.index)
# <ipython-input-421-5349a79c4939>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   enriched_tumors['sample'] = list(enriched_tumors.index)

# %%
enriched_tumors.head()
# Out:
#         patient  somatic  neoepitope  strong  weak  w/s_ratio          source  \
# patient
# A001       A001      164          30      25     5   0.200000  Enriched_Tumor
# A029       A029      197          29      29     0   0.000000  Enriched_Tumor
# A034       A034      165          56      53     3   0.056604  Enriched_Tumor
# A036       A036      279          29      27     2   0.074074  Enriched_Tumor
# A042       A042      116          31      30     1   0.033333  Enriched_Tumor
#
#         signature    sample
# patient
# A001        CDK12  ADT001R1
# A029        CCNE1  ADT029R1
# A034        BRCA1  ADT034R1
# A036        BRCA1  ADT036R1
# A042        CCNE1  ADT042R1

# %%
whole_tumors.head()
# Out:
#         patient  somatic  neoepitope  strong  weak  w/s_ratio       source  \
# patient
# A001       A001       85          32      28     4   0.142857  Whole_Tumor
# A029       A029       94           4       4     0   0.000000  Whole_Tumor
# A034       A034       93          45      43     2   0.046512  Whole_Tumor
# A036       A036      153          12      12     0   0.000000  Whole_Tumor
# A042       A042       58          20      18     2   0.111111  Whole_Tumor
#
#         signature  sample
# patient
# A001        CDK12  ADH001
# A029        CCNE1  ADH029
# A034        BRCA1  ADH034
# A036        BRCA1  ADH036
# A042        CCNE1  ADH042

# %%
matched = whole_tumors.join(enriched_tumors, lsuffix="_wt", rsuffix="_et").dropna(how='any')
matched.head()
# Out:
#         patient_wt  somatic_wt  neoepitope_wt  strong_wt  weak_wt  \
# patient
# A001          A001          85             32         28        4
# A029          A029          94              4          4        0
# A034          A034          93             45         43        2
# A036          A036         153             12         12        0
# A042          A042          58             20         18        2
#
#          w/s_ratio_wt    source_wt signature_wt sample_wt patient_et  \
# patient
# A001         0.142857  Whole_Tumor        CDK12    ADH001       A001
# A029         0.000000  Whole_Tumor        CCNE1    ADH029       A029
# A034         0.046512  Whole_Tumor        BRCA1    ADH034       A034
# A036         0.000000  Whole_Tumor        BRCA1    ADH036       A036
# A042         0.111111  Whole_Tumor        CCNE1    ADH042       A042
#
#          somatic_et  neoepitope_et  strong_et  weak_et  w/s_ratio_et  \
# patient
# A001          164.0           30.0       25.0      5.0      0.200000
# A029          197.0           29.0       29.0      0.0      0.000000
# A034          165.0           56.0       53.0      3.0      0.056604
# A036          279.0           29.0       27.0      2.0      0.074074
# A042          116.0           31.0       30.0      1.0      0.033333
#
#               source_et signature_et sample_et
# patient
# A001     Enriched_Tumor        CDK12  ADT001R1
# A029     Enriched_Tumor        CCNE1  ADT029R1
# A034     Enriched_Tumor        BRCA1  ADT034R1
# A036     Enriched_Tumor        BRCA1  ADT036R1
# A042     Enriched_Tumor        CCNE1  ADT042R1

# %%
matched['signature'] = '0'
# signatures = ['FBI-1', 'FBI-2', 'HRD-Dup', 'HRD-Del', 'TD']
signatures = ['CDK12', 'CCNE1', 'BRCA1', 'BRCA2']
matched.loc[matched['signature_wt']==matched['signature_et'], 'signature'] = 'same'
for signature in signatures:    
    matched.loc[((matched['signature']=='same') & (matched['signature_wt']==signature)), 'signature'] = signature
matched.loc[matched['signature']=='0', 'signature'] = 'discordant'
print(matched.shape)
matched.head()
# Out:
# (64, 19)
#         patient_wt  somatic_wt  neoepitope_wt  strong_wt  weak_wt  \
# patient
# A001          A001          85             32         28        4
# A029          A029          94              4          4        0
# A034          A034          93             45         43        2
# A036          A036         153             12         12        0
# A042          A042          58             20         18        2
#
#          w/s_ratio_wt    source_wt signature_wt sample_wt patient_et  \
# patient
# A001         0.142857  Whole_Tumor        CDK12    ADH001       A001
# A029         0.000000  Whole_Tumor        CCNE1    ADH029       A029
# A034         0.046512  Whole_Tumor        BRCA1    ADH034       A034
# A036         0.000000  Whole_Tumor        BRCA1    ADH036       A036
# A042         0.111111  Whole_Tumor        CCNE1    ADH042       A042
#
#          somatic_et  neoepitope_et  strong_et  weak_et  w/s_ratio_et  \
# patient
# A001          164.0           30.0       25.0      5.0      0.200000
# A029          197.0           29.0       29.0      0.0      0.000000
# A034          165.0           56.0       53.0      3.0      0.056604
# A036          279.0           29.0       27.0      2.0      0.074074
# A042          116.0           31.0       30.0      1.0      0.033333
#
#               source_et signature_et sample_et signature
# patient
# A001     Enriched_Tumor        CDK12  ADT001R1     CDK12
# A029     Enriched_Tumor        CCNE1  ADT029R1     CCNE1
# A034     Enriched_Tumor        BRCA1  ADT034R1     BRCA1
# A036     Enriched_Tumor        BRCA1  ADT036R1     BRCA1
# A042     Enriched_Tumor        CCNE1  ADT042R1     CCNE1

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
n_bins = 10
alpha = 0.8
somatic_wt = counts[counts.source == 'Whole_Tumor']['somatic']
somatic_et = counts[counts.source == 'Enriched_Tumor']['somatic']

neoepitope_wt = counts[counts.source == 'Whole_Tumor']['neoepitope']
neoepitope_et = counts[counts.source == 'Enriched_Tumor']['neoepitope']

wsratio_wt = counts[counts.source == 'Whole_Tumor']['w/s_ratio']
wsratio_et = counts[counts.source == 'Enriched_Tumor']['w/s_ratio']

# %%
colors = [
    "#4292c6", # blue
    "#fd8d3c", # orange
    "#41ab5d", # green
    "#e31a1c", # red
    "#dcbeff", # lavendar
    "#88419d", # purple
    "#d94801", # dark orange
    "#b35806", # brown
    "#a6761d", # drab brown
    "#969696", # gray
    "#252525", # black
    "#006400", # dark green
    "#191970", # midnight blue
    "#ffb6c1", # light pink
    "#c71585" # medium violet red
]

# %%
# color_map = {
#     'FBI-1': "#4292c6", # blue
#     'FBI-2': "#191970", # midnight blue
#     'HRD-Dup': "#fd8d3c", # orange
#     'HRD-Del': "#41ab5d", # green
#     'TD': "#e31a1c", # red
#     'Mixed': "#969696", # gray
# }

color_map = { # 'CDK12', 'CCNE1', 'BRCA1', 'BRCA2'
    'CDK12': "#4292c6", # blue
    'CCNE1': "#191970", # midnight blue
    'BRCA1': "#fd8d3c", # orange
    'BRCA2': "#41ab5d", # green
    'discordant': "#969696", # gray
}

matched['color'] = matched['signature'].map(color_map)
print(matched.shape)
matched.head()
# Out:
# (64, 20)
#         patient_wt  somatic_wt  neoepitope_wt  strong_wt  weak_wt  \
# patient
# A001          A001          85             32         28        4
# A029          A029          94              4          4        0
# A034          A034          93             45         43        2
# A036          A036         153             12         12        0
# A042          A042          58             20         18        2
#
#          w/s_ratio_wt    source_wt signature_wt sample_wt patient_et  \
# patient
# A001         0.142857  Whole_Tumor        CDK12    ADH001       A001
# A029         0.000000  Whole_Tumor        CCNE1    ADH029       A029
# A034         0.046512  Whole_Tumor        BRCA1    ADH034       A034
# A036         0.000000  Whole_Tumor        BRCA1    ADH036       A036
# A042         0.111111  Whole_Tumor        CCNE1    ADH042       A042
#
#          somatic_et  neoepitope_et  strong_et  weak_et  w/s_ratio_et  \
# patient
# A001          164.0           30.0       25.0      5.0      0.200000
# A029          197.0           29.0       29.0      0.0      0.000000
# A034          165.0           56.0       53.0      3.0      0.056604
# A036          279.0           29.0       27.0      2.0      0.074074
# A042          116.0           31.0       30.0      1.0      0.033333
#
#               source_et signature_et sample_et signature    color
# patient
# A001     Enriched_Tumor        CDK12  ADT001R1     CDK12  #4292c6
# A029     Enriched_Tumor        CCNE1  ADT029R1     CCNE1  #191970
# A034     Enriched_Tumor        BRCA1  ADT034R1     BRCA1  #fd8d3c
# A036     Enriched_Tumor        BRCA1  ADT036R1     BRCA1  #fd8d3c
# A042     Enriched_Tumor        CCNE1  ADT042R1     CCNE1  #191970

# %%
# Histogram
plt.hist([somatic_wt, somatic_et], bins=n_bins, alpha=alpha)
plt.title('Somatic mutations histogram')
plt.legend(['Whole', 'Enriched'])
# plt.hist(counts[counts.source == 'Enriched_Tumor'][['somatic', 'neoepitope']], bins=n_bins, alpha=alpha)
# plt.legend()

# %%
# Histogram
plt.hist([neoepitope_wt, neoepitope_et], bins=n_bins, alpha=alpha)
plt.title('Neoepitopes histogram')
plt.legend(['Whole', 'Enriched'])
# plt.hist(counts[counts.source == 'Enriched_Tumor'][['somatic', 'neoepitope']], bins=n_bins, alpha=alpha)
# plt.legend()

# %%
# Histogram
plt.hist([wsratio_wt, wsratio_et], bins=n_bins, alpha=alpha)
plt.title('Neoepitope weak/strong ratio histogram')
plt.legend(['Whole', 'Enriched'])
# plt.hist(counts[counts.source == 'Enriched_Tumor'][['somatic', 'neoepitope']], bins=n_bins, alpha=alpha)
# plt.legend()

# %%
# Scatterplot
plt.figure(figsize=(6, 6), dpi=80)
fbi1 = matched[matched.signature=='FBI-1']
fbi2 = matched[matched.signature=='FBI-2']
hrddup = matched[matched.signature=='HRD-Dup']
hrddel = matched[matched.signature=='HRD-Del']
td = matched[matched.signature=='TD']
mixed = matched[matched.signature=='Mixed']

fbi1 = plt.scatter(x=fbi1.somatic_wt, y=fbi1.somatic_et, alpha=alpha, c=fbi1.color)
fbi2 = plt.scatter(x=fbi2.somatic_wt, y=fbi2.somatic_et, alpha=alpha, c=fbi2.color)
hrddup = plt.scatter(x=hrddup.somatic_wt, y=hrddup.somatic_et, alpha=alpha, c=hrddup.color)
hrddel = plt.scatter(x=hrddel.somatic_wt, y=hrddel.somatic_et, alpha=alpha, c=hrddel.color)
td = plt.scatter(x=td.somatic_wt, y=td.somatic_et, alpha=alpha, c=td.color)
mixed = plt.scatter(x=mixed.somatic_wt, y=mixed.somatic_et, alpha=alpha, c=mixed.color)

plt.plot(range(300), range(300), linestyle="dotted", color="grey")

plt.legend((fbi1, fbi2, hrddup, hrddel, td, mixed),
           ('FBI-1', 'FBI-2', 'HRD-Dup', 'HRD-Del', 'TD', 'Mixed'),
           scatterpoints=1,
           loc='lower right',
           ncol=3,
           fontsize=10)
plt.title("Somatic mutation count")
plt.xlabel("Whole tumor")
plt.ylabel("Enriched tumor")
# Out:
# Text(0, 0.5, 'Enriched tumor')

# %%
# Scatterplot
plt.figure(figsize=(6, 6), dpi=80)
fbi1 = matched[matched.signature=='FBI-1']
fbi2 = matched[matched.signature=='FBI-2']
hrddup = matched[matched.signature=='HRD-Dup']
hrddel = matched[matched.signature=='HRD-Del']
td = matched[matched.signature=='TD']
mixed = matched[matched.signature=='Mixed']

fbi1 = plt.scatter(x=fbi1.neoepitope_wt, y=fbi1.neoepitope_et, alpha=alpha, c=fbi1.color)
fbi2 = plt.scatter(x=fbi2.neoepitope_wt, y=fbi2.neoepitope_et, alpha=alpha, c=fbi2.color)
hrddup = plt.scatter(x=hrddup.neoepitope_wt, y=hrddup.neoepitope_et, alpha=alpha, c=hrddup.color)
hrddel = plt.scatter(x=hrddel.neoepitope_wt, y=hrddel.neoepitope_et, alpha=alpha, c=hrddel.color)
td = plt.scatter(x=td.neoepitope_wt, y=td.neoepitope_et, alpha=alpha, c=td.color)
mixed = plt.scatter(x=mixed.neoepitope_wt, y=mixed.neoepitope_et, alpha=alpha, c=mixed.color)

plt.plot(range(100), range(100), linestyle="dotted", color="grey")

plt.legend((fbi1, fbi2, hrddup, hrddel, td, mixed),
           ('FBI-1', 'FBI-2', 'HRD-Dup', 'HRD-Del', 'TD', 'Mixed'),
           scatterpoints=1,
           loc='lower right',
           ncol=3,
           fontsize=10)
plt.title("Neoepitope count")
plt.xlabel("Whole tumor")
plt.ylabel("Enriched tumor")
# Out:
# Text(0, 0.5, 'Enriched tumor')

# %%
# Scatterplot
plt.figure(figsize=(6, 6), dpi=80)
fbi1 = matched[matched.signature=='FBI-1']
fbi2 = matched[matched.signature=='FBI-2']
hrddup = matched[matched.signature=='HRD-Dup']
hrddel = matched[matched.signature=='HRD-Del']
td = matched[matched.signature=='TD']
mixed = matched[matched.signature=='Mixed']

fbi1 = plt.scatter(x=fbi1['w/s_ratio_wt'], y=fbi1['w/s_ratio_et'], alpha=alpha, c=fbi1.color)
fbi2 = plt.scatter(x=fbi2['w/s_ratio_wt'], y=fbi2['w/s_ratio_et'], alpha=alpha, c=fbi2.color)
hrddup = plt.scatter(x=hrddup['w/s_ratio_wt'], y=hrddup['w/s_ratio_et'], alpha=alpha, c=hrddup.color)
hrddel = plt.scatter(x=hrddel['w/s_ratio_wt'], y=hrddel['w/s_ratio_et'], alpha=alpha, c=hrddel.color)
td = plt.scatter(x=td['w/s_ratio_wt'], y=td['w/s_ratio_et'], alpha=alpha, c=td.color)
mixed = plt.scatter(x=mixed['w/s_ratio_wt'], y=mixed['w/s_ratio_et'], alpha=alpha, c=mixed.color)

plt.plot([0, 0.35], [0, 0.35], linestyle="dotted", color="grey")

plt.legend((fbi1, fbi2, hrddup, hrddel, td, mixed),
           ('FBI-1', 'FBI-2', 'HRD-Dup', 'HRD-Del', 'TD', 'Mixed'),
           scatterpoints=1,
           loc='upper left',
           ncol=3,
           fontsize=10)
plt.title("Neoepitope weak/strong ratio")
plt.xlabel("Whole tumor")
plt.ylabel("Enriched tumor")
# Out:
# Text(0, 0.5, 'Enriched tumor')

# %%
n_bins = 10
alpha = 0.8
# FBI-1      51
# HRD-Dup    29
# TD         17
# FBI-2      16
# HRD-Del     9
somatic_fbi1 = counts[counts.signature == 'FBI-1']['somatic']
somatic_fbi2 = counts[counts.signature == 'FBI-2']['somatic']
somatic_hrddup = counts[counts.signature == 'HRD-Dup']['somatic']
somatic_hrddel = counts[counts.signature == 'HRD-Del']['somatic']
somatic_td = counts[counts.signature == 'TD']['somatic']

neoepitope_fbi1 = counts[counts.signature == 'FBI-1']['neoepitope']
neoepitope_fbi2 = counts[counts.signature == 'FBI-2']['neoepitope']
neoepitope_hrddup = counts[counts.signature == 'HRD-Dup']['neoepitope']
neoepitope_hrddel = counts[counts.signature == 'HRD-Del']['neoepitope']
neoepitope_td = counts[counts.signature == 'TD']['neoepitope']

wsratio_fbi1 = counts[counts.signature == 'FBI-1']['w/s_ratio']
wsratio_fbi2 = counts[counts.signature == 'FBI-2']['w/s_ratio']
wsratio_hrddup = counts[counts.signature == 'HRD-Dup']['w/s_ratio']
wsratio_hrddel = counts[counts.signature == 'HRD-Del']['w/s_ratio']
wsratio_td = counts[counts.signature == 'TD']['w/s_ratio']

# %%
# Histogram
data = [somatic_fbi1, somatic_fbi2, somatic_hrddup, somatic_hrddel, somatic_td]
names = ['FBI-1', 'FBI-2', 'HRD-Dup', 'HRD-Del', 'TD']
plt.hist(data, bins=n_bins, alpha=alpha, color=[color_map[x] for x in names])
plt.title('Somatic mutations histogram')
plt.legend(names)

# %%
# Histogram
data = [neoepitope_fbi1, neoepitope_fbi2, neoepitope_hrddup, neoepitope_hrddel, neoepitope_td]
names = ['FBI-1', 'FBI-2', 'HRD-Dup', 'HRD-Del', 'TD']
plt.hist(data, bins=n_bins, alpha=alpha, color=[color_map[x] for x in names])
plt.title('Neoepitopes histogram')
plt.legend(names)

# %%
# Histogram
data = [wsratio_fbi1, wsratio_fbi2, wsratio_hrddup, wsratio_hrddel, wsratio_td]
names = ['FBI-1', 'FBI-2', 'HRD-Dup', 'HRD-Del', 'TD']
plt.hist(data, bins=n_bins, alpha=alpha, color=[color_map[x] for x in names])
plt.title('Neoepitopes weak/strong ratio histogram')
plt.legend(names)

# %% [markdown]
# ### Distribution line plot

# %%
sns.set_style("white")
kwargs = dict(hist_kws={'alpha': 0.5}, kde_kws={'linewidth':3}, hist=False)
sns.distplot(somatic_fbi1, label="FBI-1", color=color_map['FBI-1'], **kwargs)
sns.distplot(somatic_fbi2, label="FBI-2", color=color_map['FBI-2'], **kwargs)
sns.distplot(somatic_hrddup, label="HRD-Dup", color=color_map['HRD-Dup'], **kwargs)
sns.distplot(somatic_hrddel, label="HRD-Del", color=color_map['HRD-Del'], **kwargs)
sns.distplot(somatic_td, label="TD", color=color_map['TD'], **kwargs)
plt.legend()

plt.title('Somatic mutation distribution')
plt.xlabel("Count")
# Out:
# /home/chois7/miniconda3/envs/py39/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/chois7/miniconda3/envs/py39/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/chois7/miniconda3/envs/py39/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/chois7/miniconda3/envs/py39/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/chois7/miniconda3/envs/py39/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 0, 'Count')

# %%
sns.set_style("white")
kwargs = dict(hist_kws={'alpha': 0.5}, kde_kws={'linewidth':3}, hist=False)
sns.distplot(neoepitope_fbi1, label="FBI-1", color=color_map['FBI-1'], **kwargs)
sns.distplot(neoepitope_fbi2, label="FBI-2", color=color_map['FBI-2'], **kwargs)
sns.distplot(neoepitope_hrddup, label="HRD-Dup", color=color_map['HRD-Dup'], **kwargs)
sns.distplot(neoepitope_hrddel, label="HRD-Del", color=color_map['HRD-Del'], **kwargs)
sns.distplot(neoepitope_td, label="TD", color=color_map['TD'], **kwargs)
plt.legend()

plt.title('Neoepitope distribution')
plt.xlabel("Count")
# Out:
# /home/chois7/miniconda3/envs/py39/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/chois7/miniconda3/envs/py39/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/chois7/miniconda3/envs/py39/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/chois7/miniconda3/envs/py39/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/chois7/miniconda3/envs/py39/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 0, 'Count')

# %%
sns.set_style("white")
kwargs = dict(hist_kws={'alpha': 0.5}, kde_kws={'linewidth':3}, hist=False)
sns.distplot(wsratio_fbi1, label="FBI-1", color=color_map['FBI-1'], **kwargs)
sns.distplot(wsratio_fbi2, label="FBI-2", color=color_map['FBI-2'], **kwargs)
sns.distplot(wsratio_hrddup, label="HRD-Dup", color=color_map['HRD-Dup'], **kwargs)
sns.distplot(wsratio_hrddel, label="HRD-Del", color=color_map['HRD-Del'], **kwargs)
sns.distplot(wsratio_td, label="TD", color=color_map['TD'], **kwargs)
plt.legend()

plt.title('Neoepitope weak/strong ratio distribution')
plt.xlabel("Ratio")
# Out:
# /home/chois7/miniconda3/envs/py39/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/chois7/miniconda3/envs/py39/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/chois7/miniconda3/envs/py39/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/chois7/miniconda3/envs/py39/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# /home/chois7/miniconda3/envs/py39/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 0, 'Ratio')

# %% [markdown]
# ## *Testing grounds*

# %%
sns.set_style("white")
kwargs = dict(hist_kws={'alpha': 0.5}, kde_kws={'linewidth':2})
sns.distplot(somatic_wt, label="Whole", **kwargs)
sns.distplot(somatic_et, label="Enriched", **kwargs)
plt.legend()
# Out:
# /home/chois7/miniconda3/envs/py39/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/chois7/miniconda3/envs/py39/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
